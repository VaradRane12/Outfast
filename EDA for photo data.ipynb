# %%
import pandas as pd

# %%
df = pd.read_csv(r"Fashion Data\styles.csv")

# %%
df.head()
# Out:
#       id gender masterCategory subCategory  articleType baseColour  season  \
# 0  15970    Men        Apparel     Topwear       Shirts  Navy Blue    Fall
# 1  39386    Men        Apparel  Bottomwear        Jeans       Blue  Summer
# 2  59263  Women    Accessories     Watches      Watches     Silver  Winter
# 3  21379    Men        Apparel  Bottomwear  Track Pants      Black    Fall
# 4  53759    Men        Apparel     Topwear      Tshirts       Grey  Summer
#
#      year   usage                             productDisplayName  Unnamed: 10  \
# 0  2011.0  Casual               Turtle Check Men Navy Blue Shirt          NaN
# 1  2012.0  Casual             Peter England Men Party Blue Jeans          NaN
# 2  2016.0  Casual                       Titan Women Silver Watch          NaN
# 3  2011.0  Casual  Manchester United Men Solid Black Track Pants          NaN
# 4  2012.0  Casual                          Puma Men Grey T-shirt          NaN
#
#   Unnamed: 11
# 0         NaN
# 1         NaN
# ...

# %%
df.isna().sum()
# Out:
# id                        0
# gender                    0
# masterCategory            0
# subCategory               0
# articleType               0
# baseColour               15
# season                   21
# year                      1
# usage                   317
# productDisplayName        7
# Unnamed: 10           44446
# Unnamed: 11           44444
# dtype: int64

# %%
df.drop(["Unnamed: 10","Unnamed: 11"],axis = 1,inplace = True)

# %%
df.head()
# Out:
#       id gender masterCategory subCategory  articleType baseColour  season  \
# 0  15970    Men        Apparel     Topwear       Shirts  Navy Blue    Fall
# 1  39386    Men        Apparel  Bottomwear        Jeans       Blue  Summer
# 2  59263  Women    Accessories     Watches      Watches     Silver  Winter
# 3  21379    Men        Apparel  Bottomwear  Track Pants      Black    Fall
# 4  53759    Men        Apparel     Topwear      Tshirts       Grey  Summer
#
#      year   usage                             productDisplayName
# 0  2011.0  Casual               Turtle Check Men Navy Blue Shirt
# 1  2012.0  Casual             Peter England Men Party Blue Jeans
# 2  2016.0  Casual                       Titan Women Silver Watch
# 3  2011.0  Casual  Manchester United Men Solid Black Track Pants
# 4  2012.0  Casual                          Puma Men Grey T-shirt

# %%
df = df.apply(lambda col: col.fillna(col.mode()[0]))

# %%
df.isna().sum()
# Out:
# id                    0
# gender                0
# masterCategory        0
# subCategory           0
# articleType           0
# baseColour            0
# season                0
# year                  0
# usage                 0
# productDisplayName    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'gender', 'masterCategory', 'subCategory', 'articleType',
#        'baseColour', 'season', 'year', 'usage', 'productDisplayName'],
#       dtype='object')

# %%
df["articleType"].unique()
# Out:
# array(['Shirts', 'Jeans', 'Watches', 'Track Pants', 'Tshirts', 'Socks',
#        'Casual Shoes', 'Belts', 'Flip Flops', 'Handbags', 'Tops', 'Bra',
#        'Sandals', 'Shoe Accessories', 'Sweatshirts', 'Deodorant',
#        'Formal Shoes', 'Bracelet', 'Lipstick', 'Flats', 'Kurtas',
#        'Waistcoat', 'Sports Shoes', 'Shorts', 'Briefs', 'Sarees',
#        'Perfume and Body Mist', 'Heels', 'Sunglasses', 'Innerwear Vests',
#        'Pendant', 'Nail Polish', 'Laptop Bag', 'Scarves', 'Rain Jacket',
#        'Dresses', 'Night suits', 'Skirts', 'Wallets', 'Blazers', 'Ring',
#        'Kurta Sets', 'Clutches', 'Shrug', 'Backpacks', 'Caps', 'Trousers',
#        'Earrings', 'Camisoles', 'Boxers', 'Jewellery Set', 'Dupatta',
#        'Capris', 'Lip Gloss', 'Bath Robe', 'Mufflers', 'Tunics',
#        'Jackets', 'Trunk', 'Lounge Pants', 'Face Wash and Cleanser',
#        'Necklace and Chains', 'Duffel Bag', 'Sports Sandals',
# ...

# %%
df["subCategory"].unique()
# Out:
# array(['Topwear', 'Bottomwear', 'Watches', 'Socks', 'Shoes', 'Belts',
#        'Flip Flops', 'Bags', 'Innerwear', 'Sandal', 'Shoe Accessories',
#        'Fragrance', 'Jewellery', 'Lips', 'Saree', 'Eyewear', 'Nails',
#        'Scarves', 'Dress', 'Loungewear and Nightwear', 'Wallets',
#        'Apparel Set', 'Headwear', 'Mufflers', 'Skin Care', 'Makeup',
#        'Free Gifts', 'Ties', 'Accessories', 'Skin', 'Beauty Accessories',
#        'Water Bottle', 'Eyes', 'Bath and Body', 'Gloves',
#        'Sports Accessories', 'Cufflinks', 'Sports Equipment', 'Stoles',
#        'Hair', 'Perfumes', 'Home Furnishing', 'Umbrellas', 'Wristbands',
#        'Vouchers'], dtype=object)

# %%
df["articleType"].unique()
# Out:
# array(['Shirts', 'Jeans', 'Watches', 'Track Pants', 'Tshirts', 'Socks',
#        'Casual Shoes', 'Belts', 'Flip Flops', 'Handbags', 'Tops', 'Bra',
#        'Sandals', 'Shoe Accessories', 'Sweatshirts', 'Deodorant',
#        'Formal Shoes', 'Bracelet', 'Lipstick', 'Flats', 'Kurtas',
#        'Waistcoat', 'Sports Shoes', 'Shorts', 'Briefs', 'Sarees',
#        'Perfume and Body Mist', 'Heels', 'Sunglasses', 'Innerwear Vests',
#        'Pendant', 'Nail Polish', 'Laptop Bag', 'Scarves', 'Rain Jacket',
#        'Dresses', 'Night suits', 'Skirts', 'Wallets', 'Blazers', 'Ring',
#        'Kurta Sets', 'Clutches', 'Shrug', 'Backpacks', 'Caps', 'Trousers',
#        'Earrings', 'Camisoles', 'Boxers', 'Jewellery Set', 'Dupatta',
#        'Capris', 'Lip Gloss', 'Bath Robe', 'Mufflers', 'Tunics',
#        'Jackets', 'Trunk', 'Lounge Pants', 'Face Wash and Cleanser',
#        'Necklace and Chains', 'Duffel Bag', 'Sports Sandals',
# ...

# %%
a = list(df["articleType"].unique())

# %%
a
# Out:
# ['Shirts',
#  'Jeans',
#  'Watches',
#  'Track Pants',
#  'Tshirts',
#  'Socks',
#  'Casual Shoes',
#  'Belts',
#  'Flip Flops',
#  'Handbags',
#  'Tops',
#  'Bra',
#  'Sandals',
#  'Shoe Accessories',
#  'Sweatshirts',
#  'Deodorant',
#  'Formal Shoes',
#  'Bracelet',
#  'Lipstick',
#  'Flats',
#  'Kurtas',
#  'Waistcoat',
#  'Sports Shoes',
#  'Shorts',
#  'Briefs',
#  'Sarees',
#  'Perfume and Body Mist',
#  'Heels',
#  'Sunglasses',
#  'Innerwear Vests',
#  'Pendant',
#  'Nail Polish',
#  'Laptop Bag',
#  'Scarves',
#  'Rain Jacket',
#  'Dresses',
#  'Night suits',
#  'Skirts',
#  'Wallets',
#  'Blazers',
#  'Ring',
#  'Kurta Sets',
#  'Clutches',
#  'Shrug',
#  'Backpacks',
#  'Caps',
#  'Trousers',
#  'Earrings',
#  'Camisoles',
#  'Boxers',
#  'Jewellery Set',
#  'Dupatta',
#  'Capris',
#  'Lip Gloss',
#  'Bath Robe',
#  'Mufflers',
#  'Tunics',
#  'Jackets',
#  'Trunk',
#  'Lounge Pants',
#  'Face Wash and Cleanser',
#  'Necklace and Chains',
#  'Duffel Bag',
# ...

# %%
df["season"].unique()
# Out:
# array(['Fall', 'Summer', 'Winter', 'Spring'], dtype=object)

# %%
df["gender"].unique()
# Out:
# array(['Men', 'Women', 'Boys', 'Girls', 'Unisex'], dtype=object)

# %%
df.to_csv("Fashion Data/final_styles.csv")

# %%
df[df["id"] == 1163]
# Out:
#          id gender masterCategory subCategory articleType baseColour  season  \
# 12904  1163    Men        Apparel     Topwear     Tshirts       Blue  Summer
#
#          year   usage                                productDisplayName
# 12904  2011.0  Sports  Nike Sahara Team India Fanwear Round Neck Jersey

# %%
df[df["subCategory"] == "Innerwear"]
# Out:
#           id gender masterCategory subCategory      articleType baseColour  \
# 18     51832  Women        Apparel   Innerwear              Bra      Beige
# 47     17871    Men        Apparel   Innerwear           Briefs     Maroon
# 53     32138    Men        Apparel   Innerwear           Briefs       Blue
# 83     17885    Men        Apparel   Innerwear  Innerwear Vests       Grey
# 95     25349    Men        Apparel   Innerwear           Briefs        Red
# ...      ...    ...            ...         ...              ...        ...
# 44391  45647    Men        Apparel   Innerwear           Briefs  Navy Blue
# 44395  57382  Women        Apparel   Innerwear           Briefs      Black
# 44399  27491  Women        Apparel   Innerwear           Briefs       Pink
# 44424  15761    Men        Apparel   Innerwear  Innerwear Vests      Green
# 44429  32143    Men        Apparel   Innerwear           Briefs        Red
#
# ...

# %%
randint()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 randint()
#
# NameError: name 'randint' is not defined

# %%
for i in range(5):
    p = random.randint(0, len(a))
    print(df[df["articleType"] == a[p]])

# %%
a

# %%
ima = pd.read_csv("Fashion Data/images.csv")

# %%
ima["filename"] = ima["filename"].apply(lambda i:i.split(".")[0])

# %%
a = "51623.jpg"

# %%
a.split(".")[0]
# Out:
# ['51623', 'jpg']

# %%
ima
# Out:
#       filename                                               link
# 0        15970  http://assets.myntassets.com/v1/images/style/p...
# 1        39386  http://assets.myntassets.com/v1/images/style/p...
# 2        59263  http://assets.myntassets.com/v1/images/style/p...
# 3        21379  http://assets.myntassets.com/v1/images/style/p...
# 4        53759  http://assets.myntassets.com/v1/images/style/p...
# ...        ...                                                ...
# 44441    17036  http://assets.myntassets.com/v1/images/style/p...
# 44442     6461  http://assets.myntassets.com/v1/images/style/p...
# 44443    18842  http://assets.myntassets.com/v1/images/style/p...
# 44444    46694  http://assets.myntassets.com/v1/images/style/p...
# 44445    51623  http://assets.myntassets.com/assets/images/516...
#
# [44446 rows x 2 columns]

# %%
ima.to_csv("Fashion Data/images_final.csv")

# %%
import json

# %%
with open ("E:\downloads\styles\\1808.json","r") as file:
    data = json.load(file)

# %%
data["data"][["price","discounted","myntraRating","brandname"]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 data["data"][["price","discounted","myntraRating","brandname"]]
#
# TypeError: unhashable type: 'list'

# %%
data["data"]
# Out:
# {'id': 1808,
#  'price': 699,
#  'discountedPrice': 699,
#  'styleType': 'P',
#  'productTypeId': 295,
#  'articleNumber': '1212497',
#  'visualTag': '',
#  'productDisplayName': 'Quechua Aluminium Print Water Bottle',
#  'variantName': 'Quechua Aluminium Print Water Bottle',
#  'myntraRating': 0,
#  'catalogAddDate': 1445524255,
#  'brandName': 'Quechua',
#  'ageGroup': 'Adults-Unisex',
#  'gender': 'Unisex',
#  'baseColour': 'Purple',
#  'colour1': '',
#  'colour2': '',
#  'fashionType': 'Fashion',
#  'season': 'Fall',
#  'year': '2010',
#  'usage': 'Sports',
#  'vat': 14.5,
#  'displayCategories': 'Accessories',
#  'weight': '0',
#  'navigationId': 0,
#  'landingPageUrl': 'Water-Bottle/Quechua/Quechua-Aluminium-Print-Water-Bottle/1808/buy',
#  'articleAttributes': {},
#  'crossLinks': [{'key': 'More Water Bottle by Quechua',
#    'value': 'water-bottle?f=brand:Quechua::gender:men women'},
#   {'key': 'More Purple Water Bottle',
# ...

# %%
dic = {'Accessories': {'Accessories': ['Accessory Gift Set', 'Hair Accessory', 'Key chain', 'Messenger Bag', 'Travel Accessory', 'Water Bottle'], 'Bags': ['Backpacks', 'Clutches', 'Duffel Bag', 'Handbags', 'Laptop Bag', 'Messenger Bag', 'Mobile Pouch', 'Rucksacks', 'Tablet Sleeve', 'Travel Accessory', 'Trolley Bag', 'Waist Pouch', 'Wallets'], 'Belts': ['Belts', 'Tshirts'], 'Cufflinks': ['Cufflinks', 'Ties and Cufflinks'], 'Eyewear': ['Sunglasses'], 'Gloves': ['Gloves'], 'Headwear': ['Caps', 'Hat', 'Headband'], 'Jewellery': ['Bangle', 'Bracelet', 'Earrings', 'Jewellery Set', 'Necklace and Chains', 'Pendant', 'Ring'], 'Mufflers': ['Mufflers'], 'Perfumes': ['Perfume and Body Mist'], 'Scarves': ['Scarves'], 'Shoe Accessories': ['Shoe Accessories', 'Shoe Laces'], 'Socks': ['Socks'], 'Sports Accessories': ['Wristbands'], 'Stoles': ', 'Kurtas', 'Kurtis', 'Lehenga Choli', 'Nehru Jackets', 'Rain Jacket', 'Rompers', 'Shirts', 'Shrug', 'Suits', 'Suspenders', 'Sweaters', 'Sweatshirts', 'Tops', 'Tshirts', 'Tunics', 'Wai', 'Kurtas', 'Kurtis', 'Lehenga Choli', 'Nehru Jackets', 'Rain Jacket', 'Rompers', 'Shirts', 'Shrug', 'Suits', 'Suspenders', 'Sweaters', 'Sweatshirts', 'Tops', 'Tshirts', 'Tunics', 'Waistcoat']}, 'Footwear': {'Flip Flops': ['Flip Flops'], 'Sandal': ['Flip Flops', 'Sandals', 'Sports Sandals'], 'Shoes': ['Casual Shoes', 'Flats', 'Formal Shoes', 'Heels', 'Sandals', 'Sports Shoes']}, 'Free Items': {'Free Gifts': ['Backpacks', 'Clutches', 'Free Gifts', 'Handbags', 'Laptop Bag', 'Scarves', 'Ties', 'Wallets'], 'Vouchers': ['Ipad']}, 'Home': {'Home Furnishing': ['Cushion Covers']}, 'Personal Care': {'Bath and Body': ['Body Lotion', 'Body Wash and Scrub', 'Nail Essentials'], 'Beauty Accessories': ['Beauty Accessory'], 'Eyes': ['Eyeshadow', 'Kajal and Eyeliner', 'Mascara'], 'Fragrance': ['Deodorant', 'Fragrance Gift Set', 'Perfume and Body Mist'], 'Hair': ['Hair Colour'], 'Lips': ['Lip Care', 'Lip Gloss', 'Lip Liner', 'Lip Plumper', 'Lipstick'], 'Makeup': ['Compact', 'Concealer', 'Eyeshadow', 'Foundation and Primer', 'Highlighter and Blush', 'Kajal and Eyeliner', 'Makeup Remover'], 'Nails': ['Nail Polish'], 'Perfumes': ['Perfume and Body Mist'], 'Skin': ['Body Lotion', 'Face Moisturisers', 'Face Scrub and Exfoliator', 'Face Serum and Gel', 'Mask and Peel'], 'Skin Care': ['Eye Cream', 'Face Moisturisers', 'Face Scrub and Exfoliator', 'Face Wash and Cleanser', 'Mask and Peel', 'Mens Grooming Kit', 'Sunscreen', 'Toner']}, 'Sporting Goods': {'Sports Equipment': ['Basketballs', 'Footballs'], 'Wristbands': ['Wristbands']}}
# Out:
#   Cell In[1], line 1
# ...

# %%
dic = {'Accessories': {'Accessories': ['Accessory Gift Set', 'Hair Accessory', 'Key chain', 'Messenger Bag', 'Travel Accessory', 'Water Bottle'], 'Bags': ['Backpacks', 'Clutches', 'Duffel Bag', 'Handbags', 'Laptop Bag', 'Messenger Bag', 'Mobile Pouch', 'Rucksacks', 'Tablet Sleeve', 'Travel Accessory', 'Trolley Bag', 'Waist Pouch', 'Wallets'], 'Belts': ['Belts', 'Tshirts'], 'Cufflinks': ['Cufflinks', 'Ties and Cufflinks'], 'Eyewear': ['Sunglasses'], 'Gloves': ['Gloves'], 'Headwear': ['Caps', 'Hat', 'Headband'], 'Jewellery': ['Bangle', 'Bracelet', 'Earrings', 'Jewellery Set', 'Necklace and Chains', 'Pendant', 'Ring'], 'Mufflers': ['Mufflers'], 'Perfumes': ['Perfume and Body Mist'], 'Scarves': ['Scarves'], 'Shoe Accessories': ['Shoe Accessories', 'Shoe Laces'], 'Socks': ['Socks'], 'Sports Accessories': ['Wristbands'], 'Stoles':[ ', 'Kurtas', 'Kurtis', 'Lehenga Choli', 'Nehru Jackets', 'Rain Jacket', 'Rompers', 'Shirts', 'Shrug', 'Suits', 'Suspenders', 'Sweaters', 'Sweatshirts', 'Tops', 'Tshirts', 'Tunics', 'Wai', 'Kurtas', 'Kurtis', 'Lehenga Choli', 'Nehru Jackets', 'Rain Jacket', 'Rompers', 'Shirts', 'Shrug', 'Suits', 'Suspenders', 'Sweaters', 'Sweatshirts', 'Tops', 'Tshirts', 'Tunics', 'Waistcoat']}, 'Footwear': {'Flip Flops': ['Flip Flops'], 'Sandal': ['Flip Flops', 'Sandals', 'Sports Sandals'], 'Shoes': ['Casual Shoes', 'Flats', 'Formal Shoes', 'Heels', 'Sandals', 'Sports Shoes']}, 'Free Items': {'Free Gifts': ['Backpacks', 'Clutches', 'Free Gifts', 'Handbags', 'Laptop Bag', 'Scarves', 'Ties', 'Wallets'], 'Vouchers': ['Ipad']}, 'Home': {'Home Furnishing': ['Cushion Covers']}, 'Personal Care': {'Bath and Body': ['Body Lotion', 'Body Wash and Scrub', 'Nail Essentials'], 'Beauty Accessories': ['Beauty Accessory'], 'Eyes': ['Eyeshadow', 'Kajal and Eyeliner', 'Mascara'], 'Fragrance': ['Deodorant', 'Fragrance Gift Set', 'Perfume and Body Mist'], 'Hair': ['Hair Colour'], 'Lips': ['Lip Care', 'Lip Gloss', 'Lip Liner', 'Lip Plumper', 'Lipstick'], 'Makeup': ['Compact', 'Concealer', 'Eyeshadow', 'Foundation and Primer', 'Highlighter and Blush', 'Kajal and Eyeliner', 'Makeup Remover'], 'Nails': ['Nail Polish'], 'Perfumes': ['Perfume and Body Mist'], 'Skin': ['Body Lotion', 'Face Moisturisers', 'Face Scrub and Exfoliator', 'Face Serum and Gel', 'Mask and Peel'], 'Skin Care': ['Eye Cream', 'Face Moisturisers', 'Face Scrub and Exfoliator', 'Face Wash and Cleanser', 'Mask and Peel', 'Mens Grooming Kit', 'Sunscreen', 'Toner']}, 'Sporting Goods': {'Sports Equipment': ['Basketballs', 'Footballs'], 'Wristbands': ['Wristbands']}}
# Out:
#   Cell In[2], line 1
# ...

# %%
import json

# %%
import pandas as pd

df = pd.read_json('category_tree.json')

print(df.to_string())
# Out:
#                                                                                                                                                                                   Accessories                                                                                                                                                                                                     Apparel                                                           Footwear                                                                       Free Items              Home                                                                                                                          Personal Care            Sporting Goods
# ...

# %%
df
# Out:
#                                                                 Accessories  \
# Accessories               [Accessory Gift Set, Hair Accessory, Key chain...
# Bags                      [Backpacks, Clutches, Duffel Bag, Handbags, La...
# Belts                                                      [Belts, Tshirts]
# Cufflinks                                   [Cufflinks, Ties and Cufflinks]
# Eyewear                                                        [Sunglasses]
# Gloves                                                             [Gloves]
# Headwear                                              [Caps, Hat, Headband]
# Jewellery                 [Bangle, Bracelet, Earrings, Jewellery Set, Ne...
# Mufflers                                                         [Mufflers]
# Perfumes                                            [Perfume and Body Mist]
# Scarves                                                           [Scarves]
# ...

# %%
import json

# Read the JSON file
with open('category_tree.json', 'r') as file:
    data = json.load(file)

# data is now a dictionary
print(data)
# Out:
# {'Accessories': {'Accessories': ['Accessory Gift Set', 'Hair Accessory', 'Key chain', 'Messenger Bag', 'Travel Accessory', 'Water Bottle'], 'Bags': ['Backpacks', 'Clutches', 'Duffel Bag', 'Handbags', 'Laptop Bag', 'Messenger Bag', 'Mobile Pouch', 'Rucksacks', 'Tablet Sleeve', 'Travel Accessory', 'Trolley Bag', 'Waist Pouch', 'Wallets'], 'Belts': ['Belts', 'Tshirts'], 'Cufflinks': ['Cufflinks', 'Ties and Cufflinks'], 'Eyewear': ['Sunglasses'], 'Gloves': ['Gloves'], 'Headwear': ['Caps', 'Hat', 'Headband'], 'Jewellery': ['Bangle', 'Bracelet', 'Earrings', 'Jewellery Set', 'Necklace and Chains', 'Pendant', 'Ring'], 'Mufflers': ['Mufflers'], 'Perfumes': ['Perfume and Body Mist'], 'Scarves': ['Scarves'], 'Shoe Accessories': ['Shoe Accessories', 'Shoe Laces'], 'Socks': ['Socks'], 'Sports Accessories': ['Wristbands'], 'Stoles': ['Stoles'], 'Ties': ['Ties'], 'Umbrellas': ['Umbrellas'], 'Wallets': ['Wallets'], 'Watches': ['Watches'], 'Water Bottle': ['Water Bottle']}, 'Apparel': {'Apparel Set':
# ...

# %%
for master , subdict in data.items():
    print("master: ", master)
    print("subdict: ",subdict)
# Out:
# master:  Accessories
# subdict:  {'Accessories': ['Accessory Gift Set', 'Hair Accessory', 'Key chain', 'Messenger Bag', 'Travel Accessory', 'Water Bottle'], 'Bags': ['Backpacks', 'Clutches', 'Duffel Bag', 'Handbags', 'Laptop Bag', 'Messenger Bag', 'Mobile Pouch', 'Rucksacks', 'Tablet Sleeve', 'Travel Accessory', 'Trolley Bag', 'Waist Pouch', 'Wallets'], 'Belts': ['Belts', 'Tshirts'], 'Cufflinks': ['Cufflinks', 'Ties and Cufflinks'], 'Eyewear': ['Sunglasses'], 'Gloves': ['Gloves'], 'Headwear': ['Caps', 'Hat', 'Headband'], 'Jewellery': ['Bangle', 'Bracelet', 'Earrings', 'Jewellery Set', 'Necklace and Chains', 'Pendant', 'Ring'], 'Mufflers': ['Mufflers'], 'Perfumes': ['Perfume and Body Mist'], 'Scarves': ['Scarves'], 'Shoe Accessories': ['Shoe Accessories', 'Shoe Laces'], 'Socks': ['Socks'], 'Sports Accessories': ['Wristbands'], 'Stoles': ['Stoles'], 'Ties': ['Ties'], 'Umbrellas': ['Umbrellas'], 'Wallets': ['Wallets'], 'Watches': ['Watches'], 'Water Bottle': ['Water Bottle']}
# ...
